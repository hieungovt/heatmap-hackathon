# %% [markdown]
# # 05 - Summary and Story
#
# Primary use case: **Equitable Access**.
#
# This notebook summarizes key findings from previous notebooks and aligns evidence to the Judge Evaluation Form.

# %%
import sys
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
if not (ROOT / 'src').exists() and (ROOT.parent / 'src').exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.data_loading import load_clean_hospital_data

# %%
df = load_clean_hospital_data()

summary = {
    'total_facilities': int(len(df)),
    'states_covered': int(df['STATE'].nunique()),
    'adult_trauma_centers': int((df['TRAUMA_ADULT'] == True).sum()),
    'pediatric_trauma_centers': int((df['TRAUMA_PEDS'] == True).sum()),
    'adult_burn_centers': int((df['BURN_ADULT'] == True).sum()),
    'pediatric_burn_centers': int((df['BURN_PEDS'] == True).sum()),
}
pd.Series(summary)
# Out:
# total_facilities            635
# states_covered               50
# adult_trauma_centers        565
# pediatric_trauma_centers    146
# adult_burn_centers          120
# pediatric_burn_centers       89
# dtype: int64

# %% [markdown]
# ## Judge-form aligned narrative
#
# - **Use case alignment**: Findings focus on equitable access to trauma and burn services.
# - **Method quality**: Data cleaning, aggregation, and population-adjusted metrics are reproducible.
# - **Actionability**: States with lowest per-capita bed access are priority targets for intervention and deeper local analysis.
#
# Next, integrate county-level population + SDOH datasets for finer equity diagnostics.
